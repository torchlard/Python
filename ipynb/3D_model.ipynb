# %%
import numpy as np
import matplotlib.pyplot as plt

x1=2499
x2=2996
y1=3349
y2=3837

dat=np.zeros((x2-x1,y2-y1))


f=fits.open('/home/lkit/Data/Jan_data/30mas_v0.5_f814w.fits')
print f[0].data
for i in xrange(x1,x2):
    for j in xrange(y1,y2):
        a=i-x1; b=j-y1
        dat[a,b]=(f[0].data[i])[j]
f.close()

fig = plt.figure()#figsize=(6, 3.2))

ax = fig.add_subplot(111)
# ax.set_title('colorMap')  #title
# plt.imshow(dat)
#ax.set_aspect('equal')
x=np.arange(x1,x2,1)
y=np.arange(y1,y2,1)
#z=dat[x,y]
ax = Axes3D(fig)
#x, y = np.meshgrid(x, y)
ax.plot_surface(x, y,dat(x,y) , rstride=1, cstride=1, cmap='hot')
# cax = fig.add_axes([0.12, 0.1, 0.78, 0.8])
# cax.get_xaxis().set_visible(False)
# cax.get_yaxis().set_visible(False)
# cax.patch.set_alpha(0)
# cax.set_frame_on(False)
# plt.colorbar(orientation='vertical')
plt.show()
# Out:
# [[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,  -2.33649029e-04
#     3.23010638e-04   3.04432731e-04]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,  -7.51029234e-04
#    -8.83585482e-04  -8.64662230e-04]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   4.44757134e-05
#    -8.27662530e-04  -7.46857841e-04]
#  ...,
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-303-18a080524d6d> in <module>()
#      25 y=np.arange(y1,y2,1)
#      26 #z=dat[x,y]
# ---> 27 ax = Axes3D(fig)
#      28 #x, y = np.meshgrid(x, y)
#      29 ax.plot_surface(x, y,dat(x,y) , rstride=1, cstride=1, cmap='hot')
#
# NameError: name 'Axes3D' is not defined

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits
import scipy.ndimage


x1=2499
x2=2996
y1=3349
y2=3837
fig = plt.figure()
ax = fig.gca(projection='3d')
#dat=np.zeros((x2-x1,y2-y1))

# f=fits.open('/home/lkit/Data/Jan_data/30mas_v0.5_f814w.fits')
# for i in xrange(x1,x2):
#     for j in xrange(y1,y2):
#         a=i-x1; b=j-y1
#         dat[a,b]=(f[0].data[i])[j]
# f.close()
f=open('/home/lkit/tmp/30mas_v0.5_bcg1.txt')
dat=[map(float,line.split()) for line in f]
f.close()

newd=[]
for d in dat:
    newd=newd+d
newd=np.asarray(newd)
newd=np.reshape(newd,(y2-y1+1,x2-x1+1))

#zum = scipy.ndimage.zoom(dat, 3)

X = np.arange((x2-x1+1)*1)
Y = np.arange((y2-y1+1)*1)
X, Y = np.meshgrid(X, Y)
#Z=dat[X,Y]
print dat

# R = np.sqrt(X**2 + Y**2)
# Z = np.sin(R)
surf = ax.plot_surface(X, Y, newd, rstride=1, cstride=1 , cmap=cm.coolwarm,
                       linewidth=0, antialiased=False
 0.00941468], [0.00865309, 0.00753621, 0.00711799, 0.00746313, 0.00784952, 0.0087555], [0.00857051, 0.00810523, 0.0091055, 0.0083958, 0.00791871, 0.00840859], [0.00896194, 0.00969564, 0.0085451, 0.00918632, 0.00946662, 0.00935858], [0.00904835, 0.00946973, 0.0103272, 0.00994125, 0.0100722, 0.0105102], [0.00954519, 0.0100678, 0.0104065, 0.010205, 0.00948596, 0.00960755], [0.00929388, 0.0110055, 0.0119743, 0.0110485, 0.0101052, 0.0105665], [0.0105941, 0.0109667, 0.0105722, 0.0110383, 0.0113357, 0.0103017], [0.010095, 0.0109178, 0.0109347, 0.0106424, 0.0109673, 0.0107675], [0.0100929, 0.0107573, 0.0112311, 0.0104783, 0.0112797, 0.0110659], [0.010312, 0.0106321, 0.0105665, 0.0100663, 0.00954539, 0.0104895], [0.0103626, 0.010685, 0.0106413, 0.0109847, 0.0108272, 0.0107105], [0.0113813, 0.0110049, 0.00909905, 0.00899909, 0.00951251, 0.00943101], [0.0101999, 0.00966677, 0.00974973, 0.0101395, 0.0103168, 0.0093392], [0.00910981, 0.00975834, 0.00966159, 0.00979319, 0.0104002, 0.00974877], [0.00923813, 0.00898536, 0.00859996, 0.00927136, 0.00965229, 0.00978755], [0.0105302, 0.00988937, 0.00924285, 0.00784445, 0.00775468, 0.0086225], [0.00836345, 0.00813423, 0.00892577, 0.0100613, 0.00865136, 0.00852729], [0.00871701, 0.00973859, 0.00937806, 0.00945154, 0.00971569, 0.0106402], [0.0102588, 0.0100716, 0.00991764, 0.0103738, 0.0098431, 0.00889948], [0.00879957, 0.00960923, 0.00948424, 0.00887458, 0.00875538, 0.00917177], [0.00808632, 0.00835098, 0.00871131, 0.0087218, 0.00832628, 0.00744664], [0.00750229, 0. ...
# /usr/lib/python2.7/dist-packages/matplotlib/collections.py:571: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-4e338ed045fe> in <module>()
#      51 fig.colorbar(surf, shrink=0.5, aspect=5)
#      52
# ---> 53 plt.show()
#
# /usr/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in show(*args, **kw)
#     153     """
#     154     global _show
# --> 155     return _show(*args, **kw)
#     156
#     157
#
# /usr/lib/python2.7/dist-packages/matplotlib/backend_bases.pyc in __call__(self, block)
#     182
#     183         if not is_interactive() or get_backend() == 'WebAgg':
# --> 184             self.mainloop()
#     185
#     186     def mainloop(self):
#
# /usr/lib/python2.7/dist-packages/matplotlib/backends/backend_tkagg.pyc in mainloop(self)
#      69 class Show(ShowBase):
#      70     def mainloop(self):
# ---> 71         Tk.mainloop()
#      72
#      73 show = Show()
#
# /usr/lib/python2.7/lib-tk/Tkinter.py in mainloop(n)
#     415 def mainloop(n=0):
#     416     """Run the main loop of Tcl."""
# --> 417     _default_root.tk.mainloop(n)
#     418
#     419 getint = int
#
# AttributeError: 'NoneType' object has no attribute 'tk'
