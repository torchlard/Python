# %%
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt

# flux4_435a=[107544.519785,117521.711737,96531.4382845]
# flux9_435a=[12529.584694,10243.3323091,11747.3110]
# err4_435a=[980.279,941.3265,855.1388]
# err9_435a=[437.1898,368.5207,272.3180]
t435=46260.; t105= 2335.206516 ; t814= 79744.0 ; t160=2411.749268
t140=4235.274168000001

#flux1=[62114.,40760.9,28449.7]
#flux1=np.asarray([1.598,3.964,3.67])*t435
#flux1=np.asarray([6.293,14.542,12.537])*t814
del1=[1335.6,1249.4,770.98]
area1=[654,1327,1313]

#flux4=[107275.,120484.,94612.3]
#flux4=np.asarray([2.311,2.591,2.205])*t435
del4=[417.9,718.2,331.3]
area4=[1460,1228,1121]

#flux6=[95967.2,69339,103902.6]
#flux6=np.asarray([24.871,30.461,32.891])*t105
del6=[6800,6764.6,7151.8]
area6=[3547,3282,4304]

#flux9=[11746.,10300.9,12465.98]
#flux9=np.asarray([0.27,0.215,0.277])*t435
del9=[134.6,102.5,133.2]
area9=[202,200,216]

#mag1=[16.7595,11.9527,12.1554]
#mag4=[5.5329,6.53753,4.1253]   #ver81(sys4)
#mag6=[6.47561,4.19941,5.536]
#mag9=[3.2267,5.70405,5.85724]

mag1=[7.90174,9.07285,10.7977]
mag4=[4.18165,5.99801,3.71509]
mag6=[4.19941,5.536,6.47561]
mag9=[2.41547,5.20147,5.02835]

# flux4_435b=[107275.,120484.,94612.3]
# flux9_435b=[12465.98,10300.9,11746]
# err4_435b=[417.9,718.2,331.3]
# err9_435b=[133.2,102.5,134.6]

# error4_435a=[0]*3; error4_435b=[0]*3
# error4_475a=[0]*3; error4_475b=[0]*3
# error9_435a=[0]*3; error9_435b=[0]*3
# error9_475a=[0]*3; error9_475b=[0]*3
# mag_ratio1a=[0]*3; mag_ratio1b=[0]*3
# mag_ratio4a=[0]*3; mag_ratio4b=[0]*3
# mag_ratio6a=[0]*3; mag_ratio6b=[0]*3
# mag_ratio9a=[0]*3; mag_ratio9b=[0]*3
# flux_ratio1a=[0]*3; flux_ratio1b=[0]*3  
# flux_ratio6a=[0]*3; flux_ratio6b=[0]*3  
# flux_ratio9a=[0]*3; flux_ratio9b=[0]*3  
# flux_ratio4a=[0]*3; flux_ratio4b=[0]*3 
# flux_mag9a=[0]*3; flux_mag9b=[0]*3
# flux_mag6a=[0]*3; flux_mag6b=[0]*3
# flux_mag4a=[0]*3; flux_mag4b=[0]*3
# flux_mag1a=[0]*3; flux_mag1b=[0]*3
# flux1_435a=[0]*3; flux1_435b=[0]*3
error1=[0]*3
mag_ratio1=[0]*3
flux_ratio1=[0]*3
flux_mag1=[0]*3

error4=[0]*3
mag_ratio4=[0]*3
flux_ratio4=[0]*3
flux_mag4=[0]*3

error6=[0]*3
mag_ratio6=[0]*3
flux_ratio6=[0]*3
flux_mag6=[0]*3

error9=[0]*3
mag_ratio9=[0]*3
flux_ratio9=[0]*3
flux_mag9=[0]*3

for i in range(3): # gen. mag,flux ratio
#     mag_ratio4a[i]=mag4[i]/mag4[(i+1)%3]
#     flux_ratio4a[i]=flux4_435a[i]/flux4_435a[(i+1)%3]
#     flux_mag4a[i]=flux_ratio4a[i]/mag_ratio4a[i]
#     mag_ratio9a[i]=mag9[i]/mag9[(i+1)%3]
#     flux_ratio9a[i]=flux9_435a[i]/flux9_435a[(i+1)%3]
#     flux_mag9a[i]=flux_ratio9a[i]/mag_ratio9a[i]
    mag_ratio1[i]=mag1[i]/mag1[(i+1)%3]
    flux_ratio1[i]=flux1[i]/flux1[(i+1)%3]
    flux_mag1[i]=flux_ratio1[i]/mag_ratio1[i]
    mag_ratio4[i]=mag4[i]/mag4[(i+1)%3]
    flux_ratio4[i]=flux4[i]/flux4[(i+1)%3]
    flux_mag4[i]=flux_ratio4[i]/mag_ratio4[i]
    mag_ratio6[i]=mag6[i]/mag6[(i+1)%3]
    flux_ratio6[i]=flux6[i]/flux6[(i+1)%3]
    flux_mag6[i]=flux_ratio6[i]/mag_ratio6[i]
    mag_ratio9[i]=mag9[i]/mag9[(i+1)%3]
    flux_ratio9[i]=flux9[i]/flux9[(i+1)%3]
    flux_mag9[i]=flux_ratio9[i]/mag_ratio9[i]
#     mag_ratio4b[i]=mag4[i]/mag4[(i+1)%3]
#     flux_ratio4b[i]=flux4_435b[i]/flux4_435b[(i+1)%3]
#     flux_mag4b[i]=flux_ratio4b[i]/mag_ratio4b[i]
#     mag_ratio9b[i]=mag9[i]/mag9[(i+1)%3]
#     flux_ratio9b[i]=flux9_435b[i]/flux9_435b[(i+1)%3]
#     flux_mag9b[i]=flux_ratio9b[i]/mag_ratio9b[i]
        
for i in range(3):  # generate error
#     error4_435a[i]=flux4_435a[i]/flux4_435a[(i+1)%3]*\
#     sqrt(pow(err4_435a[i]/flux4_435a[i],2)+pow(err4_435a[(i+1)%3]/flux4_435a[(i+1)%3],2))
#     error4_435b[i]=flux4_435b[i]/flux4_435b[(i+1)%3]*\
#     sqrt(pow(err4_435b[i]/flux4_435b[i],2)+pow(err4_435b[(i+1)%3]/flux4_435b[(i+1)%3],2))
#     error4_475[i]=(flux4_475[i]/flux4_475[(i+1)%3])*\
#     sqrt(pow(err4_475[i]/flux4_475[i],2)+pow(err4_475[(i+1)%3]/flux4_475[(i+1)%3],2))
#     error9_435a[i]=flux9_435a[i]/flux9_435a[(i+1)%3]*\
#     sqrt(pow(err9_435a[i]/flux9_435a[i],2)+pow(err9_435a[(i+1)%3]/flux9_435a[(i+1)%3],2))
#     error9_435b[i]=flux9_435b[i]/flux9_435b[(i+1)%3]*\
#     sqrt(pow(err9_435b[i]/flux9_435b[i],2)+pow(err9_435b[(i+1)%3]/flux9_435b[(i+1)%3],2))
#     error9_475[i]=(flux9_475[i]/flux9_475[(i+1)%3])*\
#     sqrt(pow(err9_475[i]/flux9_475[i],2)+pow(err9_475[(i+1)%3]/flux9_475[(i+1)%3],2))
    error1[i]=flux1[i]/flux1[(i+1)%3]*\
    sqrt(pow(del1[i]/flux1[i],2)+pow(del1[(i+1)%3]/flux1[(i+1)%3],2))
    error4[i]=flux4[i]/flux4[(i+1)%3]*\
    sqrt(pow(del4[i]/flux4[i],2)+pow(del4[(i+1)%3]/flux4[(i+1)%3],2))
    error6[i]=flux6[i]/flux6[(i+1)%3]*\
    sqrt(pow(del6[i]/flux6[i],2)+pow(del6[(i+1)%3]/flux6[(i+1)%3],2))
    error9[i]=flux9[i]/flux9[(i+1)%3]*\
    sqrt(pow(del9[i]/flux9[i],2)+pow(del9[(i+1)%3]/flux9[(i+1)%3],2))
#     mag_ratio6[i]=mag6[i]/mag6[(i+1)%3]
#     flux_ratio6[i]=flux6_814[i]/flux6_814[(i+1)%3]
#     flux_mag6[i]=flux_ratio6[i]/mag_ratio6[i]
    
#     mag_ratio9[i]=mag9[i]/mag9[(i+1)%3]
#     flux_ratio9[i]=flux9_475[i]/flux9_475[(i+1)%3]
#     flux_mag9[i]=flux_ratio9[i]/mag_ratio9[i]

#for i in range(3):
#     mag_ratio1[i]=mag1[i]/mag2[2-i]   #4:9
#     mag_ratio2[i]=mag5[(i+2)%3]/mag2[2-i]   #6:9
#    mag_ratio3[i]=mag1[i]/mag5[(i+2)%3]   #4:6
#     flux_ratio1[i]=flux3[i]/flux4[2-i]   #4(435):9(435)
#     flux_ratio2[i]=flux5[(i+2)%3]/flux4[2-i]   #6:9
#     flux_ratio[i]=flux4_435[i]/flux6_814[(i+2)%3]   #4:6
#     flux_ratio4[i]=flux1[i]/flux2[2-i]   #4(475):9(475)

x1=np.arange(0,3)
x2=np.arange(0.1,3.1)
x3=np.arange(0.2,3.2)
x4=np.arange(3,6)
x5=np.arange(3.1,6.1)
x6=np.arange(3.2,6.2)
x7=np.arange(6,9)
x8=np.arange(6.1,9.1)
x9=np.arange(6.2,9.2)
x10=np.arange(9,12)
x11=np.arange(9.1,12.1)
x12=np.arange(9.2,12.2)

y=[1]*12

#plt.figure()
plt.errorbar(x1,flux_ratio1,fmt='o',yerr=error1,c='b',label='flux ratio')
plt.plot(x2,mag_ratio1,'o',c='g',label='magnification ratio')
plt.plot(x3,flux_mag1,'o',c='r',label='flux ratio:mag ratio')

plt.errorbar(x4,flux_ratio4,fmt='o',yerr=error4,c='b')#,label='flux ratio(gaussian)')
plt.plot(x5,mag_ratio4,'o',c='g')#,label='magnification ratio')
plt.plot(x6,flux_mag4,'o',c='r')#,label='flux ratio:mag ratio')

plt.errorbar(x7,flux_ratio6,fmt='o',yerr=error6,c='b')#,label='flux ratio(gaussian)')
plt.plot(x8,mag_ratio6,'o',c='g')#,label='magnification ratio')
plt.plot(x9,flux_mag6,'o',c='r')#,label='flux ratio:mag ratio')

plt.errorbar(x10,flux_ratio9,fmt='o',yerr=error9,c='b')#,label='flux ratio(gaussian)')
plt.plot(x11,mag_ratio9,'o',c='g')#,label='magnification ratio')
plt.plot(x12,flux_mag9,'o',c='r')#,label='flux ratio:mag ratio')



#plt.errorbar(x2,flux_ratio6,fmt='o',yerr=error6_105,label='flux ratio(noise)')

# plt.errorbar(x2,flux_ratio4,yerr=error4_475,fmt='o',label='flux ratio')

# plt.plot(x1,mag_ratio1,'o',label='magnification ratio')
# plt.errorbar(x2,flux_ratio1,yerr=error4_475,fmt='o',label='flux ratio')
# plt.plot(x3,flux_mag1,'o',label='flux ratio:mag ratio')
plt.axis([-1, 12,0,3.0])    #control plot dimensions
#plt.xlim(-0.5,2.5)
plt.legend(loc='lower center', shadow=True, bbox_to_anchor=(0.5, -0.05),
          fancybox=True, ncol=3)
plt.suptitle('overview',fontsize=20)

plt.text(0.,0.2,'1.1/1.2',fontsize=10)
plt.text(1.,0.25,'1.2/1.3',fontsize=10)
plt.text(2.,0.2,'1.3/1.1',fontsize=10)
plt.text(3.,0.25,'4.1/4.2',fontsize=10)
plt.text(4.,0.2,'4.2/4.3',fontsize=10)
plt.text(5.,0.25,'4.3/4.1',fontsize=10)
plt.text(6.,0.2,'6.1/6.2',fontsize=10)
plt.text(7.,0.25,'6.2/6.3',fontsize=10)
plt.text(8.,0.2,'6.3/6.1',fontsize=10)
plt.text(9.,0.25,'9.1/9.2',fontsize=10)
plt.text(10.,0.2,'9.2/9.3',fontsize=10)
plt.text(11.,0.25,'9.3/9.1',fontsize=10)

# plt.text(3.,0.2,'24.1/24.2')
# plt.text(4.,0.2,'24.2/24.3')
# plt.text(5.,0.2,'24.3/24.1')

# plt.text(0.,0.2,'l4.1/l6.3')
# plt.text(1.,0.2,'m4.2/m6.1')
# plt.text(2.,0.2,'r4.3/r6.2')
# plt.text(0.,0.2,'l6.3/l9.3')
# plt.text(1.,0.2,'m6.1/m9.2')
# plt.text(2.,0.2,'r6.2/r9.1')
# plt.text(0.,0.2,'l4.1/l9.3')
# plt.text(1.,0.2,'m4.2/m9.2')
# plt.text(2.,0.2,'r4.3/r9.1')

# plt.text(-0.8,0.6,'1.2 1.3 1.1')
# plt.text(-0.8,0.5,'4.1 4.2 4.3')
# plt.text(-0.8,0.4,'6.3 6.1 6.2')
# plt.text(-0.8,0.3,'9.3 9.2 9.1')
xx=range(12)

plt.plot(xx,y)
plt.show()

# %%
x1=np.arange(0,3)
x2=np.arange(4,7)
x3=np.arange(8,11)
x4=np.arange(12,15)
x5=np.arange(16,19)

area1=[654,1327,1313]
area4=[1460,1228,1121]
area6=[3547,3282,4304]
area9=[202,200,216]

# norm14=sum(flux1)/sum(flux4)
# norm16=sum(flux1)/sum(flux6)
# norm19=sum(flux1)/sum(flux9)
# norm46=sum(flux4)/sum(flux6)
# norm49=sum(flux4)/sum(flux9)
# norm69=sum(flux6)/sum(flux9)
norm14=sum(area1)/sum(area4)
norm16=sum(area1)/sum(area6)
norm19=sum(area1)/sum(area9)
norm46=sum(area4)/sum(area6)
norm49=sum(area4)/sum(area9)
norm69=sum(area6)/sum(area9)

r14=[0]*3; r16=[0]*3; r19=[0]*3
r46=[0]*3; r49=[0]*3; r69=[0]*3;
for i in range(3):
#     r14[i]=flux1[i]/flux4[i]/norm14
#     r16[i]=flux1[i]/flux6[i]/norm16
#     r19[i]=flux1[i]/flux9[i]/norm19
#     r46[i]=flux4[i]/flux6[i]/norm46
#     r49[i]=flux4[i]/flux9[i]/norm49
#     r69[i]=flux6[i]/flux9[i]/norm69
#plt.xlim(-1,18)
	r14[i]=area1[i]/area4[i]/norm14
	r16[i]=area1[i]/area6[i]/norm16
	r19[i]=area1[i]/area9[i]/norm19
	r46[i]=area4[i]/area6[i]/norm46
	r49[i]=area4[i]/area9[i]/norm49
	r69[i]=area6[i]/area9[i]/norm69

plt.axis([-1, 20,-1,3.0]) 

plt.plot(x1,r14,'o')    
plt.plot(x2,r16,'o')
plt.plot(x3,r46,'o')
plt.plot(x4,r49,'o')
plt.plot(x5,r69,'o')

pos1=np.arange(-0.5,2.3).tolist()
pos2=np.arange(3.5,6.3).tolist()
pos3=np.arange(7.5,10.3).tolist()
pos4=np.arange(11.5,14.3).tolist()
pos5=np.arange(15.5,18.3).tolist()
pos=[]
pos=pos1+pos2+pos3+pos4+pos5

hei=-0.3; hei8=0.0

plt.text(pos[0],hei,'1.1/4.1',fontsize=10)
plt.text(pos[1],hei8,'1.2/4.2',fontsize=10)
plt.text(pos[2],hei,'1.3/4.3',fontsize=10)
plt.text(pos[3],hei8,'1.1/6.1',fontsize=10)
plt.text(pos[4],hei,'1.2/6.2',fontsize=10)
plt.text(pos[5],hei8,'1.3/6.3',fontsize=10)
plt.text(pos[6],hei,'4.1/6.1',fontsize=10)
plt.text(pos[7],hei8,'4.2/6.2',fontsize=10)
plt.text(pos[8],hei,'4.3/6.3',fontsize=10)
plt.text(pos[9],hei8,'4.1/9.1',fontsize=10)
plt.text(pos[10],hei,'4.2/9.2',fontsize=10)
plt.text(pos[11],hei8,'4.3/9.3',fontsize=10)
plt.text(pos[12],hei,'6.1/9.1',fontsize=10)
plt.text(pos[13],hei8,'6.2/9.2',fontsize=10)
plt.text(pos[14],hei,'6.3/9.3',fontsize=10)
plt.show()

plt.axis([-1, 3,-1,3.0]) 
plt.plot(x1,r19,'o')

plt.text(0.,0.,'1.1/9.1',fontsize=10)
plt.text(1.,0.,'1.2/9.2',fontsize=10)
plt.text(2.,0.,'1.3/9.3',fontsize=10)

plt.show()

# %%
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
x=np.arange(500)/100.
y=sqrt(337)/40.*39.37*x
plt.plot(x,y)
plt.show()
